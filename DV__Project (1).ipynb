# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/SuperStoreOrders.csv')
df.head()
# Out:
#           order_id  order_date   ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040  01-01-2011  06-01-2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883  01-01-2011  08-01-2011  Standard Class      Joseph Holt
# 2     HU-2011-1220  01-01-2011  05-01-2011    Second Class    Annie Thurman
# 3  IT-2011-3647632  01-01-2011  05-01-2011    Second Class     Eugene Moren
# 4    IN-2011-47883  01-01-2011  08-01-2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name sales quantity  \
# ...

# %%
df.tail()
# Out:
#             order_id  order_date   ship_date       ship_mode  \
# 994  ES-2011-1001989  11-03-2011  14-03-2011     First Class
# 995    IN-2011-22249  11-03-2011  15-03-2011  Standard Class
# 996   MX-2011-154620  11-03-2011  16-03-2011  Standard Class
# 997   CA-2011-158337  11-03-2011  14-03-2011    Second Class
# 998   CA-2011-114790  11-03-2011  13-03-2011    Second Class
#
#         customer_name    segment       state        country market   region  \
# 994  Maureen Fritzler  Corporate      Berlin        Germany     EU  Central
# 995  Speros Goranitis   Consumer  Queensland      Australia   APAC  Oceania
# 996        Karen Seio  Corporate   Guatemala      Guatemala  LATAM  Central
# 997    Kelly Andreada   Consumer    New York  United States     US     East
# 998     Filia McAdams  Corporate    Kentucky  United States     US    South
#
#      ...         category sub_category  \
# 994  ...  Office Supplies      Binders
# 995  ...       Technology  Accessories
# ...

# %%
df.describe()
# Out:
#          quantity    discount       profit  shipping_cost    year
# count  999.000000  999.000000   999.000000     999.000000   999.0
# mean     3.338338    0.144511    26.758064      26.075465  2011.0
# std      2.324316    0.227657   177.858090      53.634203     0.0
# min      1.000000    0.000000 -1475.352000       0.110000  2011.0
# 25%      2.000000    0.000000     0.000000       2.600000  2011.0
# 50%      3.000000    0.000000     9.331200       7.920000  2011.0
# 75%      4.000000    0.200000    36.645000      24.050000  2011.0
# max     14.000000    0.800000  2939.310000     665.270000  2011.0

# %%
df.shape
# Out:
# (999, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        999 non-null    object
#  1   order_date      999 non-null    object
#  2   ship_date       999 non-null    object
#  3   ship_mode       999 non-null    object
#  4   customer_name   999 non-null    object
#  5   segment         999 non-null    object
#  6   state           999 non-null    object
#  7   country         999 non-null    object
#  8   market          999 non-null    object
#  9   region          999 non-null    object
#  10  product_id      999 non-null    object
#  11  category        999 non-null    object
#  12  sub_category    999 non-null    object
#  13  product_name    999 non-null    object
#  14  sales           999 non-null    object
#  15  quantity        999 non-null    int64
#  16  discount        999 non-null    float64
# ...

# %%
df.nunique()
# Out:
# order_id          491
# order_date         69
# ship_date          72
# ship_mode           4
# customer_name     375
# segment             3
# state             259
# country            86
# market              7
# region             13
# product_id        929
# category            3
# sub_category       17
# product_name      802
# sales             418
# quantity           14
# discount           22
# profit            910
# shipping_cost     819
# order_priority      4
# year                1
# dtype: int64

# %%
df["segment"].value_counts()
# Out:
# Consumer       539
# Corporate      282
# Home Office    178
# Name: segment, dtype: int64

# %%
df["state"].value_counts()
# Out:
# Texas               19
# California          18
# National Capital    18
# England             17
# Virginia            15
#                     ..
# Al Jawf              1
# Karnataka            1
# Kampala              1
# Manitoba             1
# Anzoátegui           1
# Name: state, Length: 259, dtype: int64

# %%
df["country"].value_counts()
# Out:
# United States               169
# France                       62
# Australia                    52
# Germany                      38
# Nigeria                      34
#                            ...
# Niger                         1
# Central African Republic      1
# Uganda                        1
# Czech Republic                1
# Argentina                     1
# Name: country, Length: 86, dtype: int64

# %%
df["category"].value_counts()
# Out:
# Office Supplies    611
# Technology         205
# Furniture          183
# Name: category, dtype: int64

# %%
df["category"].unique()
# Out:
# array(['Office Supplies', 'Furniture', 'Technology'], dtype=object)

# %%
df["state"].nunique()
# Out:
# 259

# %%
df["country"].nunique()
# Out:
# 86

# %%
df['order_date'] = df['order_date'].astype('datetime64[ns]')
df['ship_date'] = df['ship_date'].astype('datetime64[ns]')
df['sales'] = pd.to_numeric(df['sales'], errors='coerce')
# Out:
# <ipython-input-136-af829ffe05e8>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['order_date'] = df['order_date'].astype('datetime64[ns]')
# <ipython-input-136-af829ffe05e8>:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['ship_date'] = df['ship_date'].astype('datetime64[ns]')

# %%
df.isnull().sum()
# Out:
# order_id           0
# order_date         0
# ship_date          0
# ship_mode          0
# customer_name      0
# segment            0
# state              0
# country            0
# market             0
# region             0
# product_id         0
# category           0
# sub_category       0
# product_name       0
# sales             44
# quantity           0
# discount           0
# profit             0
# shipping_cost      0
# order_priority     0
# year               0
# dtype: int64

# %%
df = df.dropna(subset=['sales'])

# %%
df.shape
# Out:
# (955, 21)

# %% [markdown]
# The "year" column is being dropped from the dataset because it contains identical values for all rows. In other words, every data point in the "year" column is the same, which means this column does not provide any useful information for analysis.

# %%
 df=df.drop(columns=['year'])

# %%
df.shape
# Out:
# (955, 20)

# %%
df.isnull().sum()
# Out:
# order_id          0
# order_date        0
# ship_date         0
# ship_mode         0
# customer_name     0
# segment           0
# state             0
# country           0
# market            0
# region            0
# product_id        0
# category          0
# sub_category      0
# product_name      0
# sales             0
# quantity          0
# discount          0
# profit            0
# shipping_cost     0
# order_priority    0
# dtype: int64

# %% [markdown]
# **Univariate Analysis:**
#
# Univariate analysis involves examining a single variable in isolation. It helps in understanding the distribution, central tendency, and variability of the variable. Common techniques include:
#
# **Bivariate Analysis:**
#
# Bivariate analysis involves the analysis of two variables simultaneously to understand the relationship between them.
#
# **Multivariate Analysis:**
#
# Multivariate analysis involves the analysis of three or more variables to understand complex relationships.

# %% [markdown]
# # **Univariate Analysis**

# %%
# Extract the Data Visualization scores
data_sales = df['sales']

# Descriptive statistics
mean = data_sales.mean()
median = data_sales.median()
mode = data_sales.mode()[0]
std_dev = data_sales.std()

print(f"Mean: {mean}")
print(f"Median: {median}")
print(f"Mode: {mode}")
print(f"Standard Deviation: {std_dev}")
sales_data = df['sales']

# Create a histogram using Matplotlib
plt.figure(figsize=(8, 6))
plt.hist(sales_data, bins=10, color='skyblue', edgecolor='black')

# Set labels and title
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.title('Histogram of Sales')

# Show the chart
plt.show()
# Out:
# Mean: 166.61884816753926
# Median: 80.0
# Mode: 19.0
# Standard Deviation: 205.29858926813236

# %% [markdown]
# **Conclusion : Descriptive Statistics:**
#
# Mean:The mean sales value is approximately 166.61. This represents the average sales amount per observation in your dataset.
# Median: The median sales value is 80.0. The median is the middle value when the data is sorted in ascending order.
# Mode: The mode suggests that the sales value of 19.0 is the most frequently occurring value in your dataset.
#
# Standard Deviation:The standard deviation of approximately 205.29 measures the spread or variability of your sales data.
# Count Plot:

# %% [markdown]
# **Q.Which segment is best seller?**

# %%
segment_counts = df['segment'].value_counts()
segments = segment_counts.index
count_values = segment_counts.values
print(segment_counts)
# Create a count plot using Matplotlib
plt.figure(figsize=(8, 6))
plt.bar(segments, count_values, color='skyblue')

# Set labels and title
plt.xlabel('Segment')
plt.ylabel('Count')
plt.title('Count Plot of Segments')

# Rotate x-axis labels for better readability if needed
plt.xticks(rotation=45)

# Show the chart
plt.show()
# Out:
# Consumer       513
# Corporate      269
# Home Office    173
# Name: segment, dtype: int64

# %% [markdown]
# Conclusion:
# The Consumer segment has the highest count, indicating that it is the most prevalent customer segment. Corporate comes next, followed by Home Office. Understanding the distribution of customers across these segments is valuable for targeted marketing, sales strategies, and customer relationship management. Businesses can tailor their approaches to meet the specific needs and preferences of each segment for optimized customer satisfaction and overall performance.

# %% [markdown]
# **Q: Which Region has the highest order count and In which Region do we need to grow our Business?**

# %%
df["region"].value_counts()
# Out:
# Central           224
# Africa            131
# South             121
# EMEA              112
# Oceania            67
# Southeast Asia     67
# North              47
# North Asia         47
# West               43
# East               30
# Caribbean          29
# Central Asia       23
# Canada             14
# Name: region, dtype: int64

# %%
sns.set(rc={'figure.figsize':(15,8)})
sns.countplot(x=df['region'])
# Out:
# <Axes: xlabel='region', ylabel='count'>

# %% [markdown]
# The region with the highest order count is "Central," with 224 orders. This indicates a significant volume of business activity or customer engagement in this particular region.
#
# Region with Potential for Business Growth: "Canada" has the lowest order count among the listed regions, with 14 orders. This suggests that there may be opportunities for growth and expansion in the Canadian market. Allocating resources, implementing targeted marketing strategies, and enhancing business operations in Canada could potentially lead to increased order counts and business development.

# %% [markdown]
# **Q: What are the Highest selling and Lowest Selling Sub-Category?**

# %%
plt.figure(figsize=(12,6))
sns.countplot(x=df['sub_category'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The sub-category with the highest sales is "Binderss," recording a substantial figure of 118 units. This suggests a strong demand for binders. On the other hand, the sub-category with the lowest sales is "Tables," with only 13 units sold. This relatively lower figure may indicate a lesser demand for Tables.  Analyzing such sales data is crucial for businesses to understand market trends, optimize inventory, and make informed decisions about product offerings.

# %% [markdown]
# **Q: What are the Top 10 States with highest Order Count?**

# %%
df['state'].value_counts().head(10)
# Out:
# Texas                     19
# California                17
# National Capital          17
# Washington                15
# England                   15
# Lagos                     15
# New York                  14
# Virginia                  14
# North Rhine-Westphalia    13
# Victoria                  12
# Name: state, dtype: int64

# %%
plt.figure(figsize=(15,10))
df['state'].value_counts().head(10).plot.pie()
# Out:
# <Axes: ylabel='state'>

# %% [markdown]
# The analysis of order counts across different states reveals interesting insights into the geographical distribution of business activity. Texas emerges as the leader with the highest order count, indicating a robust market presence or significant customer base in the state. Following closely, California and the National Capital share the second position, underscoring substantial business engagements in these regions. Washington, England, and Lagos, while diverse in terms of geography, suggest an international customer reach, possibly showcasing a global market strategy. New York and Virginia demonstrate comparable order counts, reflecting considerable business activities in both states. The inclusion of North Rhine-Westphalia represents an international market in Germany, exemplifying a global business footprint. Lastly, Victoria rounds out the top 10, emphasizing a noteworthy order count in that specific region. This geographic distribution of order counts offers businesses valuable insights into their market reach, enabling them to tailor strategies for different regions and make informed decisions about resource allocation and growth opportunities.

# %% [markdown]
# **Q.How much each Sub-Category is contributing in Sales of SuperStore?**

# %%
plt.figure(figsize=(15,10))
plt.pie(df['sub_category'].value_counts(),labels=df["sub_category"].value_counts().keys(),autopct="%0.1f%%")
plt.show()

# %% [markdown]
# # **Bivariate** **Analysis**

# %%
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.boxplot(x='segment', y='sales', data=df)
plt.xlabel('Segment')
plt.ylabel('Sales')
plt.title('Box Plot of Sales by Segment')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Sales Distribution: The data shows that sales are distributed across various segments, including Consumer, Corporate, and Home Office. Each segment exhibits a different distribution of sales.
#
# Outliers: There are several outliers in the data, especially in the Corporate and Home Office segments. These outliers represent exceptionally high sales values that are significantly above the typical range.
#
# Segment Comparison: The box plot allows us to compare the sales distributions between segments. Corporate segment sales tend to have a wider range and more extreme values compared to Consumer and Home Office segments.
#
# Median Sales: The horizontal line inside each box represents the median sales value for each segment. It provides a quick reference point for the central tendency of sales in each category.
#
# Variability: The height of the boxes (interquartile range) demonstrates the variability in sales within each segment. A taller box indicates higher variability.
# Skewness: The skewness of the data can be inferred from the box plot. If a box is asymmetric (skewed to one side), it suggests a skew in the data distribution.
#
# Overall Trends: By comparing the box plots for different segments, you can identify overall trends in sales patterns. For example, you can see which segments tend to have higher or lower sales on average.
#
# Potential Focus Areas: Outliers may represent specific opportunities or challenges within each segment. These extreme values may warrant further investigation to understand their underlying causes.

# %% [markdown]
# **Q.Analyzing Profit**

# %%
df["category"].unique()
# Out:
# array(['Office Supplies', 'Furniture', 'Technology'], dtype=object)

# %%
categorical_profits = df.groupby('category').sum()[['profit']]
print(categorical_profits)
plt.figure(figsize=(10, 5))
sns.barplot(x=categorical_profits.index, y='profit', data=categorical_profits)
plt.ylabel("In millions")
plt.xlabel("Category")
plt.title("Categorical Profits")
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability

plt.show()
# Out:
# <ipython-input-153-610ca6df83e7>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   categorical_profits = df.groupby('category').sum()[['profit']]
#                      profit
# category
# Furniture        1664.47860
# Office Supplies  5201.27330
# Technology       4740.43732

# %% [markdown]
# Conclusion:
#
# Among the three categories, "Office Supplies" has the highest profit, indicating that this product category is contributing the most to the overall profitability.
#
# "Technology" follows closely behind, suggesting a strong performance in terms of profit generation.
#
# "Furniture" has the lowest profit among the three categories, indicating that it may be worth exploring strategies to improve the profitability of this product category.
#
# Understanding the profitability of different product categories is essential for businesses to optimize their product mix, pricing strategies, and resource allocation to maximize overall profitability.

# %%
categorical_sales = df.groupby('category').sum()[['sales']]
print(categorical_profits)
plt.figure(figsize=(12, 6))
sns.barplot(x=categorical_sales.index, y='sales', data=categorical_sales)
plt.xticks(rotation=45)
plt.xlabel('Category')
plt.ylabel('Sales')
plt.title('Sales by Category')
plt.show()
# Out:
# <ipython-input-154-33b83a7f961e>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   categorical_sales = df.groupby('category').sum()[['sales']]
#                      profit
# category
# Furniture        1664.47860
# Office Supplies  5201.27330
# Technology       4740.43732

# %% [markdown]
# The sales data indicates that Technology products lead in total sales, followed closely by Office Supplies. Furniture lags behind in terms of sales, presenting an opportunity for growth with strategic marketing and promotions. This insight enables businesses to allocate resources effectively and optimize strategies for each category, contributing to overall revenue maximization.

# %% [markdown]
# **Q.Analyzing Profit from each Market in the World**

# %%
market_profits = df.groupby('market').sum()[['profit']]
plt.figure(figsize=(10, 5))
sns.barplot(x=market_profits.index, y='profit', data=market_profits)
plt.ylabel("In millions")
plt.xlabel("Market")
plt.title("Market Profits")
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()
# Out:
# <ipython-input-155-1283dae0560a>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   market_profits = df.groupby('market').sum()[['profit']]
#             profit
# market
# APAC    1137.22470
# Africa  1473.86700
# Canada   455.67000
# EMEA    2541.41400
# EU      1562.94600
# LATAM   2518.60532
# US      1916.46220

# %% [markdown]
#  conclusion:
#
# 1. **LATAM (Latin America) has the Highest Profit:** Among the listed markets (APAC, Africa, Canada, EMEA, EU, LATAM, and US), LATAM stands out with the highest total profit. This indicates that the Latin American market has made a significant contribution to the overall profitability.
#
# 2. **EMEA (Europe, Middle East, and Africa) and EU (European Union) Show Strong Profits:** EMEA and EU follow closely in terms of total profit. These regions contribute substantially to the overall profitability, suggesting a robust business presence in Europe, the Middle East, and Africa.
#
# 3. **US (United States) also Contributes Significantly:** The United States, while not the top performer, still contributes a notable amount to the overall profit. This is expected, given the size and economic significance of the U.S. market.
#
# 4. **Profitable Operations in APAC (Asia-Pacific) and Africa:** The Asia-Pacific (APAC) and Africa markets also show positive profits, though not as high as LATAM, EMEA, EU, or the US. These regions, nevertheless, contribute to the overall profitability of the business.
#
# 5. **Canada Shows Moderate Profit:** Canada contributes a moderate amount to the overall profit, suggesting a stable but not the highest-performing market.
#
# 6. **Strategic Considerations:** Understanding the profit distribution across markets is crucial for strategic decision-making. Businesses can use this information to focus on high-profit regions, tailor marketing strategies, and allocate resources effectively to maximize overall profitability.

# %%
sns.scatterplot(x='sales', y='profit', data=df, alpha=0.7, hue='category', palette='Set1', legend='full', s=80)
# Customize the appearance
plt.xlabel('Sales', fontsize=14)
plt.ylabel('Profit', fontsize=14)
plt.title('Scatter Plot of Sales vs. Profit with Hue', fontsize=16)
plt.grid(True, linestyle='--', alpha=0.7)
# Add a legend
plt.legend(loc='best', fontsize=12)
plt.show()

# %% [markdown]
# The scatter plot of profit vs. sales shows a wide spread of data with no clear linear relationship. There are outliers, noise, and clustering, indicating that profit is influenced by multiple factors beyond just sales.

# %% [markdown]
# **Q: In which Region the store is giving more discount and what is the most profitable region?**

# %%
# Group by 'region', calculate the sum of 'profit', and sort the values in descending order
top_profit_regions = df.groupby(['region'])['profit'].sum().reset_index()
top_profit_regions = top_profit_regions.sort_values(by="profit", ascending=False)
# Select the top 5 regions with the highest profit
top_5_regions = top_profit_regions.nlargest(n=5, columns=['profit'])
# Define a list of colors for the bars
colors = ['skyblue', 'lightcoral', 'lightgreen', 'gold', 'lightpink']
# Create a bar plot with colorful bars
plt.figure(figsize=(10, 6))
plt.bar(top_5_regions['region'], top_5_regions['profit'], color=colors)
# Set labels and title
plt.xlabel('Region')
plt.ylabel('Total Profit')
plt.title('Top 5 Regions by Profit')
# Rotate x-axis labels for better readability
plt.xticks(rotation=45)
# Show the bar plot
plt.show()

# %% [markdown]
# EMEA is the region with the highest total profit, indicated by the blue bar. It stands out as the most profitable region among all the regions.
#
#  Central Asia follows closely behind, with the second-highest total profit, represented by the red bar. While it is slightly lower than EMEA, it is still a significant contributor to overall profit.
#
# South is the third-highest profit region, as shown by the green bar. It generates a substantial amount of profit but falls behind Central Asia and EMEA.

# %% [markdown]
# **Q: In which Region the store is giving more discount and what is the most profitable region?**

# %%
regions= df.groupby(['region']).sum().sort_values('discount', ascending=False)
regions.reset_index(inplace=True)
fig, ax = plt.subplots(figsize=(15, 5))
sns.barplot(x='region', y='discount', data=regions)
plt.xticks(rotation=90)
plt.show()
# Out:
# <ipython-input-158-a6fabea2caee>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   regions= df.groupby(['region']).sum().sort_values('discount', ascending=False)
#             region    sales  quantity  discount      profit  shipping_cost
# 0          Central  39171.0       825    31.910  1738.03974        3647.28
# 1           Africa  16354.0       322    28.800  1473.86700        2273.45
# 2   Southeast Asia  13698.0       252    18.520  -872.02530        1321.45
# 3            South  21273.0       391    14.006  1601.20206        2278.17
# 4             EMEA  15566.0       239    13.800  2541.41400        2129.11
# 5          Oceania  15886.0       266     9.300  1355.47800        1547.72
# 6            North   8345.0       157     6.606  1343.62012         967.62
# ...

# %% [markdown]
# Discount Analysis:
# The region where the store is giving the highest discount is "Central," with a discount rate of 31.910%.
#
# Profitability Analysis:
# The most profitable region is "EMEA" (Europe, Middle East, and Africa), with a total profit of 2541.41400. This indicates that EMEA contributes the most to the overall profitability of the store.
#
# Conclusion:
# While the store is providing the highest discount in the Central region, the most profitable region is EMEA. This suggests that the impact of discounts on profitability might vary across regions, and further analysis could be done to optimize discount strategies and enhance profitability in different regions.

# %% [markdown]
# **Q: Creating only Profit/Loss Dataframe to calculate Total Profit & Loss of the superstore**

# %%
df_profit=df[df['profit'] > 0]

# %%
df_loss=df[df['profit'] < 0]

# %%
Total_Profit = df_profit['profit'].sum()
print(Total_Profit)
# Out:
# 29142.36466

# %%
Total_loss=np.negative(df_loss['profit'].sum())
print("Total_loss = %.2f" %Total_loss)
# Out:
# Total_loss = 17536.18

# %%
Net_Profit = Total_Profit - Total_loss
print(Net_Profit)
# Out:
# 11606.18922

# %%
df_Net_Profit = pd.DataFrame({
    'Category': ['Total Profit', 'Total Loss', 'Net Profit'],
    'Amount': [Total_Profit, Total_loss, Net_Profit]
})

# %%
df_Net_Profit
# Out:
#        Category       Amount
# 0  Total Profit  29142.36466
# 1    Total Loss  17536.17544
# 2    Net Profit  11606.18922

# %%
# Create a horizontal bar plot
plt.figure(figsize=(10, 6))
plt.barh(df_Net_Profit['Category'], df_Net_Profit['Amount'], color=['green', 'red', 'blue'])
plt.xlabel('Amount')
plt.title('Profit and Loss Summary')
plt.gca().invert_yaxis()  # Reverse the order of categories
plt.show()

# %% [markdown]
# Total Profit: The green bar in the plot represents the total profit, which indicates the cumulative profit generated from all the data points where the profit is greater than zero. In this case, the total profit is a positive value.
#
# Total Loss: The red bar in the plot represents the total loss, which shows the cumulative loss incurred from all the data points where the profit is less than zero. This value is calculated as the negative of the sum of losses, making it a positive value.
#
# Net Profit: The blue bar in the plot represents the net profit, which is calculated as the difference between the total profit and total loss. Net profit is a key metric as it provides a holistic view of the financial performance. In this case, the net profit is positive, indicating that overall, the business has generated more profit than loss.

# %% [markdown]
# # **Multivariate** **Analysis**

# %%
# Create a pairplot with hue
g = sns.pairplot(df, hue='category')
# Set the title for the entire pairplot
g.fig.suptitle('Pairplot of Numerical Variables (Colored by Category)')
# Adjust the title position
g.fig.subplots_adjust(top=0.95)
plt.show()

# %%
correlation_matrix = df.corr()
print(correlation_matrix)
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()
# Out:
# <ipython-input-168-dc3bb48388cb>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()
#                   sales  quantity  discount    profit  shipping_cost
# sales          1.000000  0.257060 -0.103397  0.199510       0.737846
# quantity       0.257060  1.000000 -0.032598  0.025132       0.168280
# discount      -0.103397 -0.032598  1.000000 -0.504722      -0.090457
# profit         0.199510  0.025132 -0.504722  1.000000       0.188968
# shipping_cost  0.737846  0.168280 -0.090457  0.188968       1.000000

# %% [markdown]
# Conclusion:
#
# 1. **Sales and Shipping Cost (0.737846):** There is a strong positive correlation (0.738) between sales and shipping cost. This suggests that as sales increase, the associated shipping costs also tend to increase. This is a common relationship in retail, where higher sales often lead to higher shipping costs.
#
# 2. **Sales and Profit (0.199510):** There is a positive correlation (0.200) between sales and profit. While the correlation is not very strong, it indicates that, on average, higher sales are associated with higher profits. However, other factors not considered in this correlation may influence profitability.
#
# 3. **Discount and Profit (-0.504722):** There is a strong negative correlation (-0.505) between the discount offered and the profit. This suggests that as the discount increases, the profit tends to decrease. Businesses should be cautious about offering high discounts, as it may negatively impact profitability.
#
# 4. **Sales and Quantity (0.257060):** There is a positive correlation (0.257) between sales and quantity. This indicates that higher sales are associated with a higher quantity of products sold. This relationship is intuitive, as more products sold generally lead to higher sales.
#
# 5. **Sales and Discount (-0.103397):** There is a weak negative correlation (-0.103) between sales and discount. This suggests that, on average, there is a slight tendency for higher sales to be associated with lower discounts. However, the correlation is not very strong, and other factors may influence discounting strategies.
#
# In summary, the correlation matrix provides valuable insights into the relationships between different variables in the dataset. The strong negative correlation between discount and profit is particularly noteworthy, indicating the need for careful consideration of discounting strategies to maintain profitability.
